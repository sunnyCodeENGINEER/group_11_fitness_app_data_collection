# %%
import pandas as pd

# %%
workout_data = pd.read_csv("Workout.csv")
workout_data.head()
# Out:
#   Body Part Type of Muscle                   Workout Sets Reps per Set
# 0     Chest    Upper Chest    Incline dumbbell press  3-4         8-12
# 1     Chest    Upper Chest  Incline cable crossovers  3-4        10-15
# 2     Chest    Upper Chest    Incline dumbbell flyes  3-4        10-15
# 3     Chest    Lower Chest    Decline dumbbell press  3-4         8-12
# 4     Chest    Lower Chest  Decline cable crossovers  3-4        10-15

# %%
workout_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
# Body Part         52 non-null object
# Type of Muscle    52 non-null object
# Workout           52 non-null object
# Sets              52 non-null object
# Reps per Set      52 non-null object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
workout_data
# Out:
#     Body Part   Type of Muscle                      Workout  \
# 0       Chest      Upper Chest       Incline dumbbell press
# 1       Chest      Upper Chest     Incline cable crossovers
# 2       Chest      Upper Chest       Incline dumbbell flyes
# 3       Chest      Lower Chest       Decline dumbbell press
# 4       Chest      Lower Chest     Decline cable crossovers
# 5       Chest      Lower Chest       Decline dumbbell flyes
# 6       Chest  Chest Isolation                  Chest flyes
# 7       Chest  Chest Isolation             Cable crossovers
# 8       Chest  Chest Isolation               Dumbbell flyes
# 9        Back            Upper                     Pull-ups
# 10       Back            Upper                 Barbell rows
# 11       Back            Upper                Dumbbell rows
# 12       Back            Upper            Seated cable rows
# 13       Back            Lower               Bent-over rows
# 14       Back            Lower              Hyperextensions
# ...

# %%
workout_data_edited = workout_data.drop(['Sets', 'Reps per Set'], axis=1)

# %%
workout_data_edited
# Out:
#     Body Part   Type of Muscle                      Workout
# 0       Chest      Upper Chest       Incline dumbbell press
# 1       Chest      Upper Chest     Incline cable crossovers
# 2       Chest      Upper Chest       Incline dumbbell flyes
# 3       Chest      Lower Chest       Decline dumbbell press
# 4       Chest      Lower Chest     Decline cable crossovers
# 5       Chest      Lower Chest       Decline dumbbell flyes
# 6       Chest  Chest Isolation                  Chest flyes
# 7       Chest  Chest Isolation             Cable crossovers
# 8       Chest  Chest Isolation               Dumbbell flyes
# 9        Back            Upper                     Pull-ups
# 10       Back            Upper                 Barbell rows
# 11       Back            Upper                Dumbbell rows
# 12       Back            Upper            Seated cable rows
# 13       Back            Lower               Bent-over rows
# 14       Back            Lower              Hyperextensions
# ...

# %%
workout_data2 = pd.read_csv("megaGymDataset.csv")
workout_data2.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                                           Title  \
# 0              0                          Partner plank band row
# 1              1                    Banded crunch isometric hold
# 2              2                           FYR Banded Plank Jack
# 3              3                                   Banded crunch
# 4              4                                          Crunch
# 5              5                       Decline band press sit-up
# 6              6                           FYR2 Banded Frog Pump
# 7              7                          Band low-to-high twist
# 8              8                                Barbell roll-out
# 9              9                   Barbell Ab Rollout - On Knees
# 10            10                        Decline bar press sit-up
# 11            11                          Bench barbell roll-out
# 12            12                               Barbell Side Bend
# ...

# %%
workout_data2_copy = workout_data2.dropna()

# %%
workout_data2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 8 to 2913
# Data columns (total 9 columns):
# Unnamed: 0    506 non-null int64
# Title         506 non-null object
# Desc          506 non-null object
# Type          506 non-null object
# BodyPart      506 non-null object
# Equipment     506 non-null object
# Level         506 non-null object
# Rating        506 non-null float64
# RatingDesc    506 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 39.5+ KB

# %%
workout_data2_copy
# Out:
#       Unnamed: 0                                              Title  \
# 8              8                                   Barbell roll-out
# 9              9                      Barbell Ab Rollout - On Knees
# 10            10                           Decline bar press sit-up
# 11            11                             Bench barbell roll-out
# 13            13                                   Seated bar twist
# 21            21                                Kettlebell Windmill
# 39            39                           Dumbbell V-Sit Cross Jab
# 40            40                              Dumbbell spell caster
# 41            41                                 Dumbbell side bend
# 88            88                                     Landmine twist
# 89            89                              Suspended ab fall-out
# 90            90                             Decline reverse crunch
# 92            92                                  Weighted Crunches
# ...

# %%
workout_data2_copy.nunique()
# Out:
# Unnamed: 0    506
# Title         500
# Desc          474
# Type            7
# BodyPart       16
# Equipment      13
# Level           3
# Rating         54
# RatingDesc      1
# dtype: int64

# %%
workout_data2_copy.BodyPart.unique()
# Out:
# array(['Abdominals', 'Abductors', 'Adductors', 'Biceps', 'Calves',
#        'Chest', 'Forearms', 'Glutes', 'Hamstrings', 'Lats', 'Lower Back',
#        'Middle Back', 'Traps', 'Quadriceps', 'Shoulders', 'Triceps'],
#       dtype=object)

# %%
filtered_data_strength = workout_data2_copy[workout_data2_copy['Type'] == 'Strength'].copy()
filtered_data_strength
# Out:
#       Unnamed: 0                                              Title  \
# 8              8                                   Barbell roll-out
# 9              9                      Barbell Ab Rollout - On Knees
# 10            10                           Decline bar press sit-up
# 11            11                             Bench barbell roll-out
# 13            13                                   Seated bar twist
# 21            21                                Kettlebell Windmill
# 39            39                           Dumbbell V-Sit Cross Jab
# 40            40                              Dumbbell spell caster
# 41            41                                 Dumbbell side bend
# 88            88                                     Landmine twist
# 89            89                              Suspended ab fall-out
# 90            90                             Decline reverse crunch
# 92            92                                  Weighted Crunches
# ...

# %%
filtered_data_strength = filtered_data_strength.drop(['Unnamed: 0', 'Type', 'Level', 'RatingDesc'], axis=1)
filtered_data_strength
# Out:
#                                                   Title  \
# 8                                      Barbell roll-out
# 9                         Barbell Ab Rollout - On Knees
# 10                             Decline bar press sit-up
# 11                               Bench barbell roll-out
# 13                                     Seated bar twist
# 21                                  Kettlebell Windmill
# 39                             Dumbbell V-Sit Cross Jab
# 40                                Dumbbell spell caster
# 41                                   Dumbbell side bend
# 88                                       Landmine twist
# 89                                Suspended ab fall-out
# 90                               Decline reverse crunch
# 92                                    Weighted Crunches
# 93                                            Ab Roller
# 94                                              Otis-Up
# 95                           Captain's chair knee raise
# ...

# %%
filtered_data_strength.columns
# Out:
# Index(['Title', 'Desc', 'BodyPart', 'Equipment', 'Rating'], dtype='object')

# %%
filtered_data_strength.reset_index(drop=True, inplace=True)

# %%
filtered_data_strength
# Out:
#                                                  Title  \
# 0                                     Barbell roll-out
# 1                        Barbell Ab Rollout - On Knees
# 2                             Decline bar press sit-up
# 3                               Bench barbell roll-out
# 4                                     Seated bar twist
# 5                                  Kettlebell Windmill
# 6                             Dumbbell V-Sit Cross Jab
# 7                                Dumbbell spell caster
# 8                                   Dumbbell side bend
# 9                                       Landmine twist
# 10                               Suspended ab fall-out
# 11                              Decline reverse crunch
# 12                                   Weighted Crunches
# 13                                           Ab Roller
# 14                                             Otis-Up
# 15                          Captain's chair knee raise
# ...

# %%
filtered_data_strength.to_csv('filtered_data.csv', index=False)
